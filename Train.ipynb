# %%
# %cd /content/drive/Shareddrives/NLPFinalProject
# Out:
# /content/drive/Shareddrives/NLPFinalProject

# %%
# !pip install --upgrade pip
# !pip install OpenNMT-py
# Out:
# ...
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# ...
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %%
# %%bash
# cat <<EOF > data.yaml
# # toy_en_de.yaml
#
# ## Where the samples will be written
# save_data: data/example
# ## Where the vocab(s) will be written
# src_vocab: data/example.vocab.src
# tgt_vocab: data/example.vocab.tgt
# # Prevent overwriting existing files in the folder
# overwrite: False
#
# # Corpus opts:
# data:
#     corpus_1:
#         path_src: data/src-train.txt
#         path_tgt: data/tgt-train.txt
#     valid:
#         path_src: data/src-val.txt
#         path_tgt: data/tgt-val.txt
#
# EOF

# %%
# !onmt_build_vocab -config data.yaml -n_sample 10000
# Out:
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2021-05-01 16:45:28,362 INFO] Counter vocab from 10000 samples.
# [2021-05-01 16:45:28,362 INFO] Build vocab on 10000 transformed examples/corpus.
# [2021-05-01 16:45:28,376 INFO] corpus_1's transforms: TransformPipe()
# [2021-05-01 16:45:28,379 INFO] Loading ParallelCorpus(data/src-train.txt, data/tgt-train.txt, align=None)...
# [2021-05-01 16:45:29,480 INFO] Counters src:132
# [2021-05-01 16:45:29,480 INFO] Counters tgt:134
# Traceback (most recent call last):
#   File "/usr/local/bin/onmt_build_vocab", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.7/dist-packages/onmt/bin/build_vocab.py", line 66, in main
#     build_vocab_main(opts)
#   File "/usr/local/lib/python3.7/dist-packages/onmt/bin/build_vocab.py", line 53, in build_vocab_main
#     save_counter(src_counter, opts.src_vocab)
# ...

# %%
# %%bash
# cat <<EOF >> data.yaml
# # Vocabulary files that were just created
# src_vocab: data/example.vocab.src
# tgt_vocab: data/example.vocab.tgt
#
# # Train on a single GPU
# world_size: 1
# gpu_ranks: [0]
#
# # Where to save the checkpoints
# save_model: data/model/cp
# save_checkpoint_steps: 500
# train_steps: 30000
# valid_steps: 50
# gpu_ranks: 0
# EOF

# %%
# !onmt_train -config data.yaml
# Out:
# [2021-05-01 10:21:31,161 INFO] Missing transforms field for corpus_1 data, set to default: [].
# [2021-05-01 10:21:31,162 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2021-05-01 10:21:31,162 INFO] Missing transforms field for valid data, set to default: [].
# [2021-05-01 10:21:31,162 INFO] Parsed 2 corpora from -data.
# [2021-05-01 10:21:31,163 INFO] Get special vocabs from Transforms: {'src': set(), 'tgt': set()}.
# [2021-05-01 10:21:31,163 INFO] Loading vocab from text file...
# [2021-05-01 10:21:31,163 INFO] Loading src vocabulary from data/example.vocab.src
# [2021-05-01 10:21:31,164 INFO] Loaded src vocab has 132 tokens.
# [2021-05-01 10:21:31,164 INFO] Loading tgt vocabulary from data/example.vocab.tgt
# [2021-05-01 10:21:31,165 INFO] Loaded tgt vocab has 134 tokens.
# [2021-05-01 10:21:31,166 INFO] Building fields with vocab in counters...
# [2021-05-01 10:21:31,166 INFO]  * tgt vocab size: 138.
# ...

# %%
# !onmt_translate -model toy-ende/run/model_step_1000.pt -src toy-ende/src-test.txt -output toy-ende/pred_1000.txt -gpu 0 -verbose
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/onmt_translate", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.7/dist-packages/onmt/bin/translate.py", line 44, in main
#     translate(opt)
#   File "/usr/local/lib/python3.7/dist-packages/onmt/bin/translate.py", line 15, in translate
#     translator = build_translator(opt, logger=logger, report_score=True)
#   File "/usr/local/lib/python3.7/dist-packages/onmt/translate/translator.py", line 25, in build_translator
#     out_file = codecs.open(opt.output, "w+", "utf-8")
#   File "/usr/lib/python3.7/codecs.py", line 904, in open
#     file = builtins.open(filename, mode, buffering)
# FileNotFoundError: [Errno 2] No such file or directory: 'toy-ende/pred_1000.txt'
